# %%
import pandas as pd

# %% [markdown]
# # Exploración inicial de los datasets dados
#
# ## Carga y vista superficial del cabezal de los dataset

# %%
amazon_prime_df = pd.read_csv('../data/raw/amazon_prime_titles-score.csv')
disney_plus_df = pd.read_csv('../data/raw/disney_plus_titles-score.csv')
hulu_df = pd.read_csv('../data/raw/hulu_titles-score.csv')
netflix_df = pd.read_csv('../data/raw/netflix_titles-score.csv')

# %%
amazon_prime_df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
disney_plus_df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
hulu_df.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description  score
# ...

# %%
netflix_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Lo relevante aquí es investigar todos los datos relevantes para nuestra API y averiguar que estén en el mismo formato a lo largo de los distintos datasets,
# * Las variables categoricas (tipo, rating) sean uniformes a lo largo de los distintos datasets
# * La fecha de lanzamiento tenga el día, més y año en el mismo orden
# * Que la duración este escrita de misma forma
# * Que el puntaje tenga el mismo minimo y maximo

# %% [markdown]
# ## Cantidad de elementos únicos en las columnas relevantes para la transformación

# %% [markdown]
# ### Ratings

# %%
amazon_prime_df.rating.unique()
# Out:
# array([nan, '13+', 'ALL', '18+', 'R', 'TV-Y', 'TV-Y7', 'NR', '16+',
#        'TV-PG', '7+', 'TV-14', 'TV-NR', 'TV-G', 'PG-13', 'TV-MA', 'G',
#        'PG', 'NC-17', 'UNRATED', '16', 'AGES_16_', 'AGES_18_', 'ALL_AGES',
#        'NOT_RATE'], dtype=object)

# %%
disney_plus_df.rating.unique()
# Out:
# array(['TV-G', 'PG', 'TV-PG', nan, 'PG-13', 'TV-14', 'G', 'TV-Y7', 'TV-Y',
#        'TV-Y7-FV'], dtype=object)

# %%
hulu_df.rating.unique()
# Out:
# array(['TV-MA', nan, 'PG-13', 'R', 'TV-14', 'PG', 'TV-PG', 'NOT RATED',
#        'G', 'TV-G', '2 Seasons', 'TV-Y', '93 min', '4 Seasons', 'TV-Y7',
#        '136 min', '91 min', '85 min', '98 min', '89 min', '94 min',
#        '86 min', '3 Seasons', '121 min', '88 min', '101 min', '1 Season',
#        '83 min', '100 min', '95 min', '92 min', '96 min', '109 min',
#        '99 min', '75 min', '87 min', '67 min', '104 min', '107 min',
#        '84 min', '103 min', '105 min', '119 min', '114 min', '82 min',
#        '90 min', '130 min', '110 min', '80 min', '6 Seasons', '97 min',
#        '111 min', '81 min', '49 min', '45 min', '41 min', '73 min',
#        '40 min', '36 min', '39 min', '34 min', '47 min', '65 min',
#        '37 min', '78 min', '102 min', '129 min', '115 min', '112 min',
#        'NR', '61 min', '106 min', '76 min', '77 min', '79 min', '157 min',
#        '28 min', '64 min', '7 min', '5 min', '6 min', '127 min',
# ...

# %%
netflix_df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Duración

# %%
amazon_prime_df.duration.unique()
# Out:
# array(['113 min', '110 min', '74 min', '69 min', '45 min', '52 min',
#        '98 min', '131 min', '87 min', '92 min', '88 min', '93 min',
#        '94 min', '46 min', '96 min', '1 Season', '104 min', '62 min',
#        '50 min', '3 Seasons', '2 Seasons', '86 min', '36 min', '37 min',
#        '103 min', '9 min', '18 min', '14 min', '20 min', '19 min',
#        '22 min', '60 min', '6 min', '54 min', '5 min', '84 min',
#        '126 min', '125 min', '109 min', '89 min', '85 min', '56 min',
#        '40 min', '111 min', '33 min', '34 min', '95 min', '99 min',
#        '78 min', '4 Seasons', '77 min', '55 min', '53 min', '115 min',
#        '58 min', '49 min', '135 min', '91 min', '64 min', '59 min',
#        '48 min', '122 min', '90 min', '102 min', '65 min', '114 min',
#        '136 min', '70 min', '138 min', '100 min', '480 min', '4 min',
#        '30 min', '152 min', '68 min', '57 min', '7 Seasons', '31 min',
# ...

# %%
disney_plus_df.duration.unique()
# Out:
# array(['23 min', '91 min', '41 min', '1 Season', '94 min', '2 Seasons',
#        '45 min', '59 min', '4 min', '10 Seasons', '2 min', '1 min',
#        '8 min', '3 Seasons', '110 min', '11 min', '7 min', '95 min',
#        '129 min', '14 min', '5 min', '134 min', '9 min', '30 min',
#        '6 min', '22 min', '3 min', '87 min', '90 min', '93 min',
#        '101 min', '132 min', '44 min', '131 min', '104 min', '5 Seasons',
#        '52 min', '47 min', '53 min', '85 min', '92 min', '135 min',
#        '4 Seasons', '105 min', '99 min', '32 Seasons', '88 min',
#        '127 min', '106 min', '116 min', '42 min', '16 Seasons', '140 min',
#        '19 Seasons', '66 min', '115 min', '137 min', '9 Seasons',
#        '126 min', '82 min', '125 min', '54 min', '7 Seasons', '98 min',
#        '102 min', '80 min', '170 min', '97 min', '112 min', '21 min',
#        '20 min', '15 min', '19 min', '79 min', '6 Seasons', '89 min',
#        '18 min', '81 min', '148 min', '121 min', '96 min', '109 min',
# ...

# %%
hulu_df.duration.unique()
# Out:
# array([nan, '94 min', '108 min', '97 min', '104 min', '1 Season',
#        '88 min', '3 Seasons', '113 min', '6 Seasons', '87 min',
#        '7 Seasons', '2 Seasons', '4 Seasons', '84 min', '95 min',
#        '15 Seasons', '101 min', '93 min', '105 min', '12 Seasons',
#        '8 Seasons', '99 min', '112 min', '124 min', '23 Seasons',
#        '145 min', '125 min', '157 min', '41 min', '89 min', '5 Seasons',
#        '80 min', '90 min', '116 min', '102 min', '100 min', '110 min',
#        '114 min', '115 min', '130 min', '133 min', '91 min', '121 min',
#        '96 min', '107 min', '103 min', '109 min', '98 min', '119 min',
#        '106 min', '111 min', '118 min', '117 min', '136 min', '181 min',
#        '182 min', '128 min', '138 min', '126 min', '72 min', '16 Seasons',
#        '20 Seasons', '9 Seasons', '86 min', '75 min', '144 min', '26 min',
#        '76 min', '129 min', '83 min', '92 min', '127 min', '139 min',
# ...

# %%
netflix_df.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %% [markdown]
# ## Tamaño de las variables numericas a evaluar

# %%
print(amazon_prime_df.score.max()-amazon_prime_df.score.min())
# Out:
# 99

# %%
print(disney_plus_df.score.max()-disney_plus_df.score.min())
# Out:
# 99

# %%
print(hulu_df.score.max()-hulu_df.score.min())
# Out:
# 99

# %%
print(netflix_df.score.max()-netflix_df.score.min())
# Out:
# 99

# %% [markdown]
# ## Revisando las entradas en las que hay ratings invalidos o fuera de lugar

# %% [markdown]
# ### Duraciones en la columna "rating"

# %%
hulu_df[hulu_df.rating.str.contains('min', na=False)]
# Out:
#      show_id   type                                              title  \
# 108     s109  Movie                                               Maze
# 397     s398  Movie                        Gunfight at the O.K. Corral
# 495     s496  Movie                    78/52: Hitchcock's Shower Scene
# 510     s511  Movie                  Citizen Jane: Battle for the City
# 513     s514  Movie                                              Dealt
# ...      ...    ...                                                ...
# 2785   s2786  Movie  The Beatles: Eight Days a Week - The Touring Y...
# 2879   s2880  Movie                                         The Colony
# 2907   s2908  Movie                 Ron White: A Little Unprofessional
# 2958   s2959  Movie                                 (Sub) Ninja Scroll
# 2993   s2994  Movie                     Amy Winehouse: A Final Goodbye
#
#      director  cast                                   country  \
# ...

# %%
netflix_df[netflix_df.rating.str.contains('min', na=False)]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...
#
#       score
# 5541     20
# 5794     37
# 5813     76

# %% [markdown]
# ### Valores "unrated/not rate"

# %%
amazon_prime_df[amazon_prime_df.rating.str.contains('UNRATED', na=False)]
# Out:
#      show_id   type                                             title  \
# 4406   s4407  Movie                             Stranger in the House
# 4715   s4716  Movie                                           Seduced
# 5087   s5088  Movie                                       Wrong Swipe
# 5090   s5091  Movie                                     The Wrong Car
# 5092   s5093  Movie                              The Perfect Daughter
# 5107   s5108  Movie                                   Nightmare Nurse
# 5129   s5130  Movie                                  All Hallows' Eve
# 5130   s5131  Movie                                     911 Nightmare
# 5142   s5143  Movie                                      Suicide Note
# 5267   s5268  Movie                                  Marriage of Lies
# 5607   s5608  Movie                        You May Now Kill The Bride
# 5763   s5764  Movie                                       Toxic Shark
# ...

# %%
amazon_prime_df[amazon_prime_df.rating.str.contains('NOT_RATE', na=False)]
# Out:
#      show_id   type                             title  \
# 6012   s6013  Movie  Ek Tha Tiger (English Subtitled)
# 6408   s6409  Movie                       Retaliation
# 8590   s8591  Movie                       Tumbleweeds
#
#                                 director  \
# 6012                          Kabir Khan
# 6408  Ludwig Shammasian, Paul Shammasian
# 8590                         King Baggot
#
#                                                    cast country date_added  \
# 6012  Salman Khan, Katrina Kaif, Girish Karnad, Ranv...   India        NaN
# 6408  Orlando Bloom, Janet Montgomery, Charlie Creed...     NaN        NaN
# 8590  William S. Hart, Barbara Bedford, Lucien Littl...     NaN        NaN
#
#       release_year    rating duration                       listed_in  \
# 6012          2012  NOT_RATE  133 min  Action, International, Romance
# 6408          2020  NOT_RATE   96 min                        Suspense
# ...

# %% [markdown]
# ### Categorias que parecen ser duplicadas

# %%
amazon_prime_df[amazon_prime_df.rating.str.contains('AGES_18_', na=False)]
# Out:
#      show_id   type        title       director  \
# 5132   s5133  Movie  100 Streets   Jim O'Hanlon
# 5150   s5151  Movie       M.F.A.  Natalia Leite
# 5734   s5735  Movie    Plug Love    Derek Scott
#
#                                                    cast country date_added  \
# 5132  Idris Elba, Gemma Arterton, Charlie Creed-Mile...     NaN        NaN
# 5150  Francesca Eastwood, Clifton Collins Jr., Leah ...     NaN        NaN
# 5734  Murda Pain, Jessica Ryan, Sino Harris, Lance W...     NaN        NaN
#
#       release_year    rating duration                listed_in  \
# 5132          2017  AGES_18_   94 min  Action, Drama, Suspense
# 5150          2017  AGES_18_   92 min  Drama, Horror, Suspense
# 5734          2017  AGES_18_  115 min           Drama, Romance
#
#                                             description  score
# 5132  100 Streets is a powerful ensemble drama, foll...     86
# 5150  Francesca Eastwood gives a breakout performanc...     94
# ...

# %%
amazon_prime_df[amazon_prime_df.rating.str.contains('18+', na=False)]
# Out:
#      show_id     type                           title  \
# 18       s19  TV Show   Zoë Coombs Marr: Bossy Bottom
# 23       s24  TV Show                    ZeroZeroZero
# 27       s28  TV Show  Z: The Beginning of Everything
# 32       s33    Movie                    Young Lovers
# 52       s53    Movie                      Yellowneck
# ...      ...      ...                             ...
# 9625   s9626  TV Show               The Flaming Heart
# 9640   s9641    Movie       Meet the Spartans (Uncut)
# 9650   s9651    Movie                 I Can't Breathe
# 9654   s9655    Movie                    Dard Divorce
# 9656   s9657    Movie              Anaganaga Oka Nenu
#
#                            director  \
# 18                              NaN
# 23                              NaN
# 27                              NaN
# 32                       Ida Lupino
# 52                     R. John Hugh
# ...                             ...
# 9625                            NaN
# ...

# %%
amazon_prime_df[amazon_prime_df.rating.str.contains('ALL', na=False)]
# Out:
#      show_id     type                                     title  \
# 17       s18  TV Show                                Zoo Babies
# 25       s26    Movie                    Zambezi: Force of Life
# 38       s39    Movie               Yoga with Sound Meditations
# 39       s40    Movie        Yoga to Harness Your Chakra Energy
# 40       s41    Movie               Yoga to Ease Flight Anxiety
# ...      ...      ...                                       ...
# 9628   s9629    Movie                     Thalaivii (Malayalam)
# 9629   s9630    Movie                       Thalaivii (Kannada)
# 9635   s9636  TV Show     Pokémon the Series: Diamond and Pearl
# 9645   s9646  TV Show  Let's Go Cozy Coupe! - Cartoons for Kids
# 9661   s9662  TV Show                                Terrahawks
#
#                 director                                               cast  \
# 17                   NaN                         Narrator - Gillian Barlett
# ...

# %%
amazon_prime_df[amazon_prime_df.rating.str.contains('ALL_AGES', na=False)]
# Out:
#      show_id   type                                              title  \
# 5204   s5205  Movie  Little Baby Bum - Wash Your Hands Song & More ...
#
#            director cast country date_added  release_year    rating duration  \
# 5204  Cannis Holder  NaN     NaN        NaN          2020  ALL_AGES   30 min
#
#      listed_in                                        description  score
# 5204      Kids  Little Baby Bum is a fun, educational children...     60

# %%
amazon_prime_df[amazon_prime_df.rating.str.contains('NR', na=False)]
# Out:
#      show_id     type                                     title  \
# 22       s23    Movie                              Zis Boom Bah
# 33       s34    Movie           Young Love (at the Sun Factory)
# 34       s35    Movie           Young Love (at Bowery Ballroom)
# 65       s66  TV Show           Wotakoi: Love is Hard for Otaku
# 70       s71    Movie          World Inferno Friendship Society
# ...      ...      ...                                       ...
# 9558   s9559    Movie                Date Night: Making a Scene
# 9586   s9587  TV Show                                  NFL Next
# 9613   s9614    Movie  What Happens in Vegas (Extended Edition)
# 9617   s9618    Movie                      The Sitter (Unrated)
# 9653   s9654    Movie                 Date Night (Extended Cut)
#
#                 director                                               cast  \
# 22          William Nigh                            Grace Hayes, Mary Healy
# ...
